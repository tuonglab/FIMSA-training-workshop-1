# %% [markdown]
# # Applying Deep Learning to TCR Data
#
# ## Learning Objectives
#
# By the end of this notebook, you will:
#
# * Learn how deep learning is applied to TCR analysis
# * Become familiar with common machine learning libraries used in bioinformatics
# * Train and test a simple deep learning model on TCR data
# * Interpret model predictions and evaluate performance
#
# ---

# %% [markdown]
# # Exploring the TCR Dataset
#
# ## Introduction
#
# T-cell receptor (TCR) sequencing data is commonly used to study immune responses, antigen specificity, autoimmune diseases, and cancer immunology.
#
# ### What Does TCR Data Look Like?
#
# Typical TCR datasets may contain:
#
# * TCR amino acid sequences
# * V(D)J gene usage
# * Clonotype frequencies
# * Patient/sample metadata
# * Disease or antigen labels
#
# For this workshop we will only be looking at and utilising the **amino acid sequences**
#
# ### Data Splits
#
# Machine learning workflows commonly divide data into:
#
# * Training set
# * Validation set
# * Test set (external)
#
# This helps evaluate how well a model generalises to unseen data.
# For this workshop, we will only be using training and testing sets
#
# ---

# %% [markdown]
# Modern bioinformatics workflows often combine machine learning and deep learning techniques for analysing biological sequence data.
#
# ## Libraries Covered
#
# ### PyTorch
#
# PyTorch is a deep learning framework commonly used for:
#
# * Building neural networks
# * GPU acceleration
# * Automatic differentiation
# * Training deep learning models
#
# ### scikit-learn
#
# scikit-learn provides:
#
# * Classical machine learning algorithms
# * Dataset splitting utilities
# * Evaluation metrics
# * Preprocessing tools
#
# in this example, we will mostly be using sklearn's evaluation functions (ROC, F1 score)
#
# ## Key Deep Learning Concepts
#
# ### Tensors
#
# Tensors are multidimensional arrays used as the primary data structure in deep learning frameworks.
#
# ### Neural Networks
#
# Deep learning models consist of layers that learn patterns from input data.
#
# For TCR analysis, models may learn:
#
# * Sequence motifs
# * Antigen-associated patterns
# * Disease-specific signatures
#
# ---

# %% [markdown]
# #### Again, lets first install and import all the packages necessary to run this notebook

# %%
# clone the repository so that we have all the data and notebooks ready to go
# !git clone https://github.com/tuonglab/FIMSA-training-workshop-1.git

# %%
# initialise any imports
import numpy as np
import torch
import torch.nn as nn
import matplotlib.pyplot as plt
from pathlib import Path

# %% [markdown]
# #### Lets load our TCR data, we will be utilizing amino acid sequences of cancerous and healthy TCR data

# %%
# load cancer and control sequences as lists, manipulate data in lists, and then output a numpy array

cancer_training_path = "/content/FIMSA-training-workshop-1/data/tutorial_4/cancer_training_data.txt"
control_training_path = "/content/FIMSA-training-workshop-1/data/tutorial_4/control_training_data.txt"

cancer_training_seqs = [line.strip() for line in open(cancer_training_path) if line.strip()]
control_training_seqs = [line.strip() for line in open(control_training_path) if line.strip()]

print(f"Training set contains {len(cancer_training_seqs)} cancer sequences and {len(control_training_seqs)} healthy sequences")
# Out:
# ---------------------------------------------------------------------------
# FileNotFoundError                         Traceback (most recent call last)
# Cell In[2], line 6
#       3 cancer_training_path = "/content/FIMSA-training-workshop-1/data/tutorial_4/cancer_training_data.txt"
#       4 control_training_path = "/content/FIMSA-training-workshop-1/data/tutorial_4/control_training_data.txt"
# ----> 6 cancer_training_seqs = [line.strip() for line in open(cancer_training_path) if line.strip()]
#       7 control_training_seqs = [line.strip() for line in open(control_training_path) if line.strip()]
#       9 print(f"Training set contains {len(cancer_training_seqs)} cancer sequences and {len(control_training_seqs)} healthy sequences")
#
# File ~\AppData\Roaming\Python\Python312\site-packages\IPython\core\interactiveshell.py:324, in _modified_open(file, *args, **kwargs)
#     317 if file in {0, 1, 2}:
#     318     raise ValueError(
#     319         f"IPython won't let you open fd={file} by default "
#     320         "as it is likely to crash IPython. If you know what you are doing, "
#     321         "you can use builtins' open."
#     322     )
# --> 324 return io_open(file, *args, **kwargs)
#
# FileNotFoundError: [Errno 2] No such file or directory: '/content/FIMSA-training-workshop-1/data/tutorial_4/cancer_training_data.txt'

# %% [markdown]
# #### Since deep learning models can't explicitly understand text characters such as 'C' or 'D', lets convert them into a representation that can be understood by the model

# %%
# load AA indices as a dictionary
aa_index_path = "/content/FIMSA-training-workshop-1/data/tutorial_4/AAidx_PCA_2024.txt"
with open(aa_index_path) as f:
    next(f)  # skip header
    aaidx_dict = {
        p[0]: list(map(float, p[1:]))
        for line in f
        if (p := line.strip().split("\t"))
    }

num_features = len(aaidx_dict['C'])

# %%
# convert features 
def aaindex_encoding(sequence, num_features, aaidx_dict):
    sequence_length = len(sequence)
    encoded_sequence = np.zeros((sequence_length, num_features), dtype=np.float32)
    
    for position in range(sequence_length):
        current_aa = sequence[position]
        try:
            encoded_sequence[position, :] = aaidx_dict[current_aa]
        except KeyError:
            pass

    return encoded_sequence

# %%
training_data = []
training_labels = []

# convert sequences to features and labels
for seq in cancer_training_seqs:
    training_data.append(aaindex_encoding(seq, num_features, aaidx_dict))
    training_labels.append(1)

for seq in control_training_seqs:
    training_data.append(aaindex_encoding(seq, num_features, aaidx_dict))
    training_labels.append(0)

print(f"total training set contains {len(training_data)} sequences")
# Out:
# total training set contains 10000 sequences

# %% [markdown]
# # Training a Small Deep Learning Model
#
# ## Introduction
#
# Training deep learning models can take significant computational time.
#
# For this seminar, we will train a small model on a subset of the data using only a few epochs to demonstrate the workflow while keeping runtime manageable.
#
# ## Topics Covered
#
# * Creating a simple neural network
# * Preparing data for training
# * Training on a small TCR dataset
# * Monitoring loss during training
# * Understanding optimisation steps
#
# ## Training Workflow
#
# ### Step 1 — Forward Pass
#
# The model receives input sequences and generates predictions.
#
# ### Step 2 — Loss Calculation
#
# The loss function measures how different the predictions are from the true labels.
#
# ### Step 3 — Backpropagation
#
# The model updates its parameters based on prediction errors.
#
# ### Step 4 — Optimisation
#
# The optimiser adjusts model weights to improve performance.
#
# ## Epochs
#
# An epoch represents one complete pass through the training dataset.
#
# ## Monitoring Training
#
# During training, we commonly track:
#
# * Training loss
# * Validation loss (If there is a validation set)
# * Accuracy
#
# Visualising these metrics helps identify:
#
# * Model improvement
# * Overfitting
# * Training instability
#
# ## Computational Considerations
#
# Deep learning models may require:
#
# * GPUs
# * Large memory resources
# * Longer training times
#
# Training large TCR models on full datasets may take hours or days depending on model complexity.
#
# ---

# %% [markdown]
# #### Firstly we need to convert our current input to a "Tensor", which is a datatype that deep learning models use to process data

# %%
# Converting input to type 'Tensor', a data type that deep learning models use to process data
X = np.array(training_data, dtype=np.float32)
y = np.array(training_labels, dtype=np.int64)

X_tensor = torch.tensor(X)
y_tensor = torch.tensor(y)

"""
CNNs expect:
 (batch, channels, height, width)
 
our current shape is:
 (N, seq_len, features)

our shape will get converted to:
 (N, 1, features, seq_len)
"""

X_tensor = X_tensor.permute(0, 2, 1).unsqueeze(1)

print(f"Shape of the input tensor: {X_tensor.shape}")
# Out:
# Shape of the input tensor: torch.Size([10000, 1, 14, 27])

# %% [markdown]
# #### Next, we need to define the architecture of our model, for this workshop we will use a simple Convolutional Neural Network with just a few layers

# %%
#DEFINING OUR DEEP LEARNING MODEL
class SimpleTCRCNN(nn.Module):
    """
    Simple Convolutional Neural Network for classifying AAindex-encoded TCR sequences
    (e.g., cancer vs control).

    The model applies a 2D convolution over sequence features to
    capture local amino acid motifs, followed by a linear classifier.

    Parameters
    ----------
    num_features : int
        Number of AAindex features per residue.

    Input
    -----
    Tensor of shape (batch_size, 1, num_features, sequence_length)

    Output
    ------
    Tensor of shape (batch_size, 2)
        Class logits (e.g., cancer vs control).
    """

    def __init__(self, num_features):
        super().__init__()
        self.conv = nn.Conv2d(
            in_channels=1,
            out_channels=8,
            kernel_size=(num_features, 3)
        )
        self.relu = nn.ReLU()
        self.fc = nn.Linear(8 * 25, 2)

    def forward(self, x):
        x = self.conv(x)
        x = self.relu(x)
        x = x.view(x.size(0), -1)
        return self.fc(x)

# %% [markdown]
# #### After that we need to initialize our model as well as define our loss function and optimizer

# %%
# INITIALIZE MODEL
model = SimpleTCRCNN(num_features)

# LOSS + OPTIMIZER
criterion = nn.CrossEntropyLoss()

optimizer = torch.optim.Adam(
    model.parameters(),
    lr=0.001
)

# %% [markdown]
# #### After everything has been defined, we can finally begin training

# %%
# lists for storing and keeping track of losses and accuracies
train_losses = [] 
train_accuracies = []

# number of epochs/iterations to train for
num_epochs = 1000

# TRAINING LOOP
for epoch in range(num_epochs):

    outputs = model(X_tensor)
    loss = criterion(outputs, y_tensor)
    optimizer.zero_grad()
    loss.backward()
    optimizer.step()
    preds = torch.argmax(outputs, dim=1)
    accuracy = (preds == y_tensor).float().mean()

    # save metrics
    train_losses.append(loss.item())
    train_accuracies.append(accuracy.item())

    print(
        f"Epoch {epoch+1} | "
        f"Loss: {loss.item():.4f} | "
        f"Accuracy: {accuracy.item():.4f}"
    )
print("Training complete!")
# Out:
# Epoch 1 | Loss: 1.0558 | Accuracy: 0.5182
# Epoch 2 | Loss: 0.9518 | Accuracy: 0.5222
# Epoch 3 | Loss: 0.8764 | Accuracy: 0.5334
# Epoch 4 | Loss: 0.8310 | Accuracy: 0.5372
# Epoch 5 | Loss: 0.8118 | Accuracy: 0.5418
# Epoch 6 | Loss: 0.8101 | Accuracy: 0.5373
# Epoch 7 | Loss: 0.8148 | Accuracy: 0.5395
# Epoch 8 | Loss: 0.8171 | Accuracy: 0.5433
# Epoch 9 | Loss: 0.8129 | Accuracy: 0.5441
# Epoch 10 | Loss: 0.8020 | Accuracy: 0.5474
# Epoch 11 | Loss: 0.7867 | Accuracy: 0.5530
# Epoch 12 | Loss: 0.7699 | Accuracy: 0.5618
# Epoch 13 | Loss: 0.7543 | Accuracy: 0.5694
# Epoch 14 | Loss: 0.7417 | Accuracy: 0.5762
# Epoch 15 | Loss: 0.7330 | Accuracy: 0.5798
# Epoch 16 | Loss: 0.7278 | Accuracy: 0.5882
# Epoch 17 | Loss: 0.7252 | Accuracy: 0.5931
# Epoch 18 | Loss: 0.7236 | Accuracy: 0.5938
# Epoch 19 | Loss: 0.7218 | Accuracy: 0.5945
# Epoch 20 | Loss: 0.7190 | Accuracy: 0.5959
# Epoch 21 | Loss: 0.7149 | Accuracy: 0.5970
# Epoch 22 | Loss: 0.7096 | Accuracy: 0.5998
# Epoch 23 | Loss: 0.7036 | Accuracy: 0.6024
# Epoch 24 | Loss: 0.6976 | Accuracy: 0.6054
# Epoch 25 | Loss: 0.6923 | Accuracy: 0.6055
# Epoch 26 | Loss: 0.6881 | Accuracy: 0.6065
# Epoch 27 | Loss: 0.6851 | Accuracy: 0.6046
# Epoch 28 | Loss: 0.6830 | Accuracy: 0.6036
# Epoch 29 | Loss: 0.6815 | Accuracy: 0.6002
# Epoch 30 | Loss: 0.6802 | Accuracy: 0.6007
# Epoch 31 | Loss: 0.6785 | Accuracy: 0.5995
# Epoch 32 | Loss: 0.6764 | Accuracy: 0.6005
# Epoch 33 | Loss: 0.6738 | Accuracy: 0.6031
# Epoch 34 | Loss: 0.6710 | Accuracy: 0.6067
# Epoch 35 | Loss: 0.6682 | Accuracy: 0.6092
# Epoch 36 | Loss: 0.6657 | Accuracy: 0.6099
# Epoch 37 | Loss: 0.6636 | Accuracy: 0.6124
# Epoch 38 | Loss: 0.6619 | Accuracy: 0.6160
# Epoch 39 | Loss: 0.6606 | Accuracy: 0.6187
# Epoch 40 | Loss: 0.6595 | Accuracy: 0.6215
# Epoch 41 | Loss: 0.6583 | Accuracy: 0.6237
# Epoch 42 | Loss: 0.6571 | Accuracy: 0.6240
# Epoch 43 | Loss: 0.6557 | Accuracy: 0.6254
# Epoch 44 | Loss: 0.6542 | Accuracy: 0.6256
# Epoch 45 | Loss: 0.6526 | Accuracy: 0.6264
# Epoch 46 | Loss: 0.6512 | Accuracy: 0.6269
# Epoch 47 | Loss: 0.6500 | Accuracy: 0.6271
# Epoch 48 | Loss: 0.6489 | Accuracy: 0.6294
# Epoch 49 | Loss: 0.6481 | Accuracy: 0.6293
# Epoch 50 | Loss: 0.6473 | Accuracy: 0.6305
# Epoch 51 | Loss: 0.6465 | Accuracy: 0.6322
# Epoch 52 | Loss: 0.6457 | Accuracy: 0.6348
# Epoch 53 | Loss: 0.6448 | Accuracy: 0.6345
# Epoch 54 | Loss: 0.6439 | Accuracy: 0.6350
# Epoch 55 | Loss: 0.6430 | Accuracy: 0.6358
# Epoch 56 | Loss: 0.6422 | Accuracy: 0.6369
# Epoch 57 | Loss: 0.6414 | Accuracy: 0.6389
# Epoch 58 | Loss: 0.6407 | Accuracy: 0.6401
# Epoch 59 | Loss: 0.6401 | Accuracy: 0.6401
# Epoch 60 | Loss: 0.6394 | Accuracy: 0.6406
# Epoch 61 | Loss: 0.6388 | Accuracy: 0.6413
# Epoch 62 | Loss: 0.6382 | Accuracy: 0.6418
# Epoch 63 | Loss: 0.6376 | Accuracy: 0.6430
# Epoch 64 | Loss: 0.6369 | Accuracy: 0.6447
# Epoch 65 | Loss: 0.6363 | Accuracy: 0.6461
# Epoch 66 | Loss: 0.6357 | Accuracy: 0.6464
# Epoch 67 | Loss: 0.6351 | Accuracy: 0.6472
# Epoch 68 | Loss: 0.6346 | Accuracy: 0.6458
# Epoch 69 | Loss: 0.6341 | Accuracy: 0.6476
# Epoch 70 | Loss: 0.6336 | Accuracy: 0.6473
# Epoch 71 | Loss: 0.6330 | Accuracy: 0.6480
# Epoch 72 | Loss: 0.6325 | Accuracy: 0.6491
# Epoch 73 | Loss: 0.6320 | Accuracy: 0.6501
# Epoch 74 | Loss: 0.6315 | Accuracy: 0.6507
# Epoch 75 | Loss: 0.6310 | Accuracy: 0.6521
# Epoch 76 | Loss: 0.6306 | Accuracy: 0.6530
# Epoch 77 | Loss: 0.6301 | Accuracy: 0.6539
# Epoch 78 | Loss: 0.6297 | Accuracy: 0.6545
# Epoch 79 | Loss: 0.6292 | Accuracy: 0.6549
# Epoch 80 | Loss: 0.6288 | Accuracy: 0.6549
# Epoch 81 | Loss: 0.6284 | Accuracy: 0.6552
# Epoch 82 | Loss: 0.6280 | Accuracy: 0.6554
# Epoch 83 | Loss: 0.6276 | Accuracy: 0.6567
# Epoch 84 | Loss: 0.6272 | Accuracy: 0.6567
# Epoch 85 | Loss: 0.6268 | Accuracy: 0.6574
# Epoch 86 | Loss: 0.6264 | Accuracy: 0.6577
# Epoch 87 | Loss: 0.6260 | Accuracy: 0.6580
# Epoch 88 | Loss: 0.6256 | Accuracy: 0.6584
# Epoch 89 | Loss: 0.6253 | Accuracy: 0.6596
# Epoch 90 | Loss: 0.6249 | Accuracy: 0.6596
# Epoch 91 | Loss: 0.6245 | Accuracy: 0.6598
# Epoch 92 | Loss: 0.6242 | Accuracy: 0.6609
# Epoch 93 | Loss: 0.6238 | Accuracy: 0.6608
# Epoch 94 | Loss: 0.6235 | Accuracy: 0.6608
# Epoch 95 | Loss: 0.6232 | Accuracy: 0.6614
# Epoch 96 | Loss: 0.6228 | Accuracy: 0.6612
# Epoch 97 | Loss: 0.6225 | Accuracy: 0.6618
# Epoch 98 | Loss: 0.6222 | Accuracy: 0.6624
# Epoch 99 | Loss: 0.6219 | Accuracy: 0.6621
# Epoch 100 | Loss: 0.6215 | Accuracy: 0.6621
# Epoch 101 | Loss: 0.6212 | Accuracy: 0.6622
# Epoch 102 | Loss: 0.6209 | Accuracy: 0.6639
# Epoch 103 | Loss: 0.6206 | Accuracy: 0.6640
# Epoch 104 | Loss: 0.6203 | Accuracy: 0.6641
# Epoch 105 | Loss: 0.6200 | Accuracy: 0.6646
# Epoch 106 | Loss: 0.6197 | Accuracy: 0.6648
# Epoch 107 | Loss: 0.6195 | Accuracy: 0.6657
# Epoch 108 | Loss: 0.6192 | Accuracy: 0.6655
# Epoch 109 | Loss: 0.6189 | Accuracy: 0.6663
# Epoch 110 | Loss: 0.6186 | Accuracy: 0.6655
# Epoch 111 | Loss: 0.6183 | Accuracy: 0.6658
# Epoch 112 | Loss: 0.6181 | Accuracy: 0.6660
# Epoch 113 | Loss: 0.6178 | Accuracy: 0.6662
# Epoch 114 | Loss: 0.6175 | Accuracy: 0.6665
# Epoch 115 | Loss: 0.6173 | Accuracy: 0.6670
# Epoch 116 | Loss: 0.6170 | Accuracy: 0.6671
# Epoch 117 | Loss: 0.6167 | Accuracy: 0.6669
# Epoch 118 | Loss: 0.6165 | Accuracy: 0.6668
# Epoch 119 | Loss: 0.6162 | Accuracy: 0.6677
# Epoch 120 | Loss: 0.6160 | Accuracy: 0.6675
# Epoch 121 | Loss: 0.6157 | Accuracy: 0.6669
# Epoch 122 | Loss: 0.6155 | Accuracy: 0.6674
# Epoch 123 | Loss: 0.6153 | Accuracy: 0.6678
# Epoch 124 | Loss: 0.6150 | Accuracy: 0.6677
# Epoch 125 | Loss: 0.6148 | Accuracy: 0.6682
# Epoch 126 | Loss: 0.6146 | Accuracy: 0.6679
# Epoch 127 | Loss: 0.6143 | Accuracy: 0.6679
# Epoch 128 | Loss: 0.6141 | Accuracy: 0.6685
# Epoch 129 | Loss: 0.6139 | Accuracy: 0.6688
# Epoch 130 | Loss: 0.6136 | Accuracy: 0.6689
# Epoch 131 | Loss: 0.6134 | Accuracy: 0.6690
# Epoch 132 | Loss: 0.6132 | Accuracy: 0.6699
# Epoch 133 | Loss: 0.6130 | Accuracy: 0.6700
# Epoch 134 | Loss: 0.6128 | Accuracy: 0.6708
# Epoch 135 | Loss: 0.6125 | Accuracy: 0.6713
# Epoch 136 | Loss: 0.6123 | Accuracy: 0.6712
# Epoch 137 | Loss: 0.6121 | Accuracy: 0.6717
# Epoch 138 | Loss: 0.6119 | Accuracy: 0.6717
# Epoch 139 | Loss: 0.6117 | Accuracy: 0.6722
# Epoch 140 | Loss: 0.6115 | Accuracy: 0.6726
# Epoch 141 | Loss: 0.6113 | Accuracy: 0.6731
# Epoch 142 | Loss: 0.6111 | Accuracy: 0.6738
# Epoch 143 | Loss: 0.6109 | Accuracy: 0.6746
# Epoch 144 | Loss: 0.6107 | Accuracy: 0.6746
# Epoch 145 | Loss: 0.6105 | Accuracy: 0.6749
# Epoch 146 | Loss: 0.6103 | Accuracy: 0.6749
# Epoch 147 | Loss: 0.6101 | Accuracy: 0.6753
# Epoch 148 | Loss: 0.6099 | Accuracy: 0.6754
# Epoch 149 | Loss: 0.6097 | Accuracy: 0.6751
# Epoch 150 | Loss: 0.6095 | Accuracy: 0.6760
# Epoch 151 | Loss: 0.6093 | Accuracy: 0.6761
# Epoch 152 | Loss: 0.6091 | Accuracy: 0.6767
# Epoch 153 | Loss: 0.6089 | Accuracy: 0.6775
# Epoch 154 | Loss: 0.6087 | Accuracy: 0.6775
# Epoch 155 | Loss: 0.6085 | Accuracy: 0.6774
# Epoch 156 | Loss: 0.6084 | Accuracy: 0.6776
# Epoch 157 | Loss: 0.6082 | Accuracy: 0.6776
# Epoch 158 | Loss: 0.6080 | Accuracy: 0.6775
# Epoch 159 | Loss: 0.6078 | Accuracy: 0.6776
# Epoch 160 | Loss: 0.6076 | Accuracy: 0.6778
# Epoch 161 | Loss: 0.6075 | Accuracy: 0.6779
# Epoch 162 | Loss: 0.6073 | Accuracy: 0.6774
# Epoch 163 | Loss: 0.6071 | Accuracy: 0.6774
# Epoch 164 | Loss: 0.6069 | Accuracy: 0.6772
# Epoch 165 | Loss: 0.6068 | Accuracy: 0.6775
# Epoch 166 | Loss: 0.6066 | Accuracy: 0.6778
# Epoch 167 | Loss: 0.6064 | Accuracy: 0.6779
# Epoch 168 | Loss: 0.6063 | Accuracy: 0.6783
# Epoch 169 | Loss: 0.6061 | Accuracy: 0.6785
# Epoch 170 | Loss: 0.6059 | Accuracy: 0.6787
# Epoch 171 | Loss: 0.6057 | Accuracy: 0.6787
# Epoch 172 | Loss: 0.6056 | Accuracy: 0.6795
# Epoch 173 | Loss: 0.6054 | Accuracy: 0.6794
# Epoch 174 | Loss: 0.6052 | Accuracy: 0.6786
# Epoch 175 | Loss: 0.6051 | Accuracy: 0.6789
# Epoch 176 | Loss: 0.6049 | Accuracy: 0.6785
# Epoch 177 | Loss: 0.6048 | Accuracy: 0.6785
# Epoch 178 | Loss: 0.6046 | Accuracy: 0.6784
# Epoch 179 | Loss: 0.6044 | Accuracy: 0.6783
# Epoch 180 | Loss: 0.6043 | Accuracy: 0.6781
# Epoch 181 | Loss: 0.6041 | Accuracy: 0.6784
# Epoch 182 | Loss: 0.6039 | Accuracy: 0.6790
# Epoch 183 | Loss: 0.6038 | Accuracy: 0.6789
# Epoch 184 | Loss: 0.6036 | Accuracy: 0.6788
# Epoch 185 | Loss: 0.6035 | Accuracy: 0.6789
# Epoch 186 | Loss: 0.6033 | Accuracy: 0.6792
# Epoch 187 | Loss: 0.6032 | Accuracy: 0.6796
# Epoch 188 | Loss: 0.6030 | Accuracy: 0.6798
# Epoch 189 | Loss: 0.6029 | Accuracy: 0.6795
# Epoch 190 | Loss: 0.6027 | Accuracy: 0.6797
# Epoch 191 | Loss: 0.6026 | Accuracy: 0.6801
# Epoch 192 | Loss: 0.6024 | Accuracy: 0.6809
# Epoch 193 | Loss: 0.6023 | Accuracy: 0.6811
# Epoch 194 | Loss: 0.6021 | Accuracy: 0.6818
# Epoch 195 | Loss: 0.6020 | Accuracy: 0.6823
# Epoch 196 | Loss: 0.6018 | Accuracy: 0.6825
# Epoch 197 | Loss: 0.6017 | Accuracy: 0.6825
# Epoch 198 | Loss: 0.6015 | Accuracy: 0.6823
# Epoch 199 | Loss: 0.6014 | Accuracy: 0.6822
# Epoch 200 | Loss: 0.6012 | Accuracy: 0.6824
# Epoch 201 | Loss: 0.6011 | Accuracy: 0.6829
# Epoch 202 | Loss: 0.6010 | Accuracy: 0.6834
# Epoch 203 | Loss: 0.6008 | Accuracy: 0.6835
# Epoch 204 | Loss: 0.6007 | Accuracy: 0.6841
# Epoch 205 | Loss: 0.6006 | Accuracy: 0.6844
# Epoch 206 | Loss: 0.6004 | Accuracy: 0.6846
# Epoch 207 | Loss: 0.6003 | Accuracy: 0.6846
# Epoch 208 | Loss: 0.6002 | Accuracy: 0.6846
# Epoch 209 | Loss: 0.6000 | Accuracy: 0.6848
# Epoch 210 | Loss: 0.5999 | Accuracy: 0.6848
# Epoch 211 | Loss: 0.5998 | Accuracy: 0.6849
# Epoch 212 | Loss: 0.5996 | Accuracy: 0.6849
# Epoch 213 | Loss: 0.5995 | Accuracy: 0.6846
# Epoch 214 | Loss: 0.5994 | Accuracy: 0.6846
# Epoch 215 | Loss: 0.5992 | Accuracy: 0.6847
# Epoch 216 | Loss: 0.5991 | Accuracy: 0.6845
# Epoch 217 | Loss: 0.5990 | Accuracy: 0.6852
# Epoch 218 | Loss: 0.5989 | Accuracy: 0.6850
# Epoch 219 | Loss: 0.5987 | Accuracy: 0.6850
# Epoch 220 | Loss: 0.5986 | Accuracy: 0.6854
# Epoch 221 | Loss: 0.5985 | Accuracy: 0.6854
# Epoch 222 | Loss: 0.5983 | Accuracy: 0.6855
# Epoch 223 | Loss: 0.5982 | Accuracy: 0.6855
# Epoch 224 | Loss: 0.5981 | Accuracy: 0.6854
# Epoch 225 | Loss: 0.5980 | Accuracy: 0.6855
# Epoch 226 | Loss: 0.5978 | Accuracy: 0.6854
# Epoch 227 | Loss: 0.5977 | Accuracy: 0.6849
# Epoch 228 | Loss: 0.5976 | Accuracy: 0.6849
# Epoch 229 | Loss: 0.5975 | Accuracy: 0.6854
# Epoch 230 | Loss: 0.5973 | Accuracy: 0.6855
# Epoch 231 | Loss: 0.5972 | Accuracy: 0.6854
# Epoch 232 | Loss: 0.5971 | Accuracy: 0.6856
# Epoch 233 | Loss: 0.5970 | Accuracy: 0.6860
# Epoch 234 | Loss: 0.5969 | Accuracy: 0.6860
# Epoch 235 | Loss: 0.5967 | Accuracy: 0.6857
# Epoch 236 | Loss: 0.5966 | Accuracy: 0.6856
# Epoch 237 | Loss: 0.5965 | Accuracy: 0.6860
# Epoch 238 | Loss: 0.5964 | Accuracy: 0.6863
# Epoch 239 | Loss: 0.5963 | Accuracy: 0.6861
# Epoch 240 | Loss: 0.5961 | Accuracy: 0.6864
# Epoch 241 | Loss: 0.5960 | Accuracy: 0.6864
# Epoch 242 | Loss: 0.5959 | Accuracy: 0.6867
# Epoch 243 | Loss: 0.5958 | Accuracy: 0.6872
# Epoch 244 | Loss: 0.5957 | Accuracy: 0.6875
# Epoch 245 | Loss: 0.5955 | Accuracy: 0.6875
# Epoch 246 | Loss: 0.5954 | Accuracy: 0.6874
# Epoch 247 | Loss: 0.5953 | Accuracy: 0.6875
# Epoch 248 | Loss: 0.5952 | Accuracy: 0.6875
# Epoch 249 | Loss: 0.5951 | Accuracy: 0.6874
# Epoch 250 | Loss: 0.5950 | Accuracy: 0.6874
# Epoch 251 | Loss: 0.5949 | Accuracy: 0.6877
# Epoch 252 | Loss: 0.5948 | Accuracy: 0.6876
# Epoch 253 | Loss: 0.5946 | Accuracy: 0.6876
# Epoch 254 | Loss: 0.5945 | Accuracy: 0.6875
# Epoch 255 | Loss: 0.5944 | Accuracy: 0.6875
# Epoch 256 | Loss: 0.5943 | Accuracy: 0.6879
# Epoch 257 | Loss: 0.5942 | Accuracy: 0.6885
# Epoch 258 | Loss: 0.5941 | Accuracy: 0.6885
# Epoch 259 | Loss: 0.5940 | Accuracy: 0.6887
# Epoch 260 | Loss: 0.5938 | Accuracy: 0.6885
# Epoch 261 | Loss: 0.5937 | Accuracy: 0.6884
# Epoch 262 | Loss: 0.5936 | Accuracy: 0.6887
# Epoch 263 | Loss: 0.5935 | Accuracy: 0.6889
# Epoch 264 | Loss: 0.5934 | Accuracy: 0.6892
# Epoch 265 | Loss: 0.5933 | Accuracy: 0.6891
# Epoch 266 | Loss: 0.5932 | Accuracy: 0.6894
# Epoch 267 | Loss: 0.5931 | Accuracy: 0.6895
# Epoch 268 | Loss: 0.5930 | Accuracy: 0.6896
# Epoch 269 | Loss: 0.5929 | Accuracy: 0.6896
# Epoch 270 | Loss: 0.5927 | Accuracy: 0.6900
# Epoch 271 | Loss: 0.5926 | Accuracy: 0.6899
# Epoch 272 | Loss: 0.5925 | Accuracy: 0.6895
# Epoch 273 | Loss: 0.5924 | Accuracy: 0.6895
# Epoch 274 | Loss: 0.5923 | Accuracy: 0.6897
# Epoch 275 | Loss: 0.5922 | Accuracy: 0.6897
# Epoch 276 | Loss: 0.5921 | Accuracy: 0.6905
# Epoch 277 | Loss: 0.5920 | Accuracy: 0.6903
# Epoch 278 | Loss: 0.5919 | Accuracy: 0.6905
# Epoch 279 | Loss: 0.5918 | Accuracy: 0.6904
# Epoch 280 | Loss: 0.5917 | Accuracy: 0.6906
# Epoch 281 | Loss: 0.5916 | Accuracy: 0.6905
# Epoch 282 | Loss: 0.5915 | Accuracy: 0.6904
# Epoch 283 | Loss: 0.5914 | Accuracy: 0.6904
# Epoch 284 | Loss: 0.5913 | Accuracy: 0.6907
# Epoch 285 | Loss: 0.5911 | Accuracy: 0.6916
# Epoch 286 | Loss: 0.5910 | Accuracy: 0.6915
# Epoch 287 | Loss: 0.5909 | Accuracy: 0.6914
# Epoch 288 | Loss: 0.5908 | Accuracy: 0.6913
# Epoch 289 | Loss: 0.5907 | Accuracy: 0.6912
# Epoch 290 | Loss: 0.5906 | Accuracy: 0.6906
# Epoch 291 | Loss: 0.5905 | Accuracy: 0.6919
# Epoch 292 | Loss: 0.5904 | Accuracy: 0.6917
# Epoch 293 | Loss: 0.5903 | Accuracy: 0.6915
# Epoch 294 | Loss: 0.5902 | Accuracy: 0.6918
# Epoch 295 | Loss: 0.5901 | Accuracy: 0.6920
# Epoch 296 | Loss: 0.5900 | Accuracy: 0.6922
# Epoch 297 | Loss: 0.5899 | Accuracy: 0.6919
# Epoch 298 | Loss: 0.5898 | Accuracy: 0.6922
# Epoch 299 | Loss: 0.5897 | Accuracy: 0.6923
# Epoch 300 | Loss: 0.5896 | Accuracy: 0.6923
# Epoch 301 | Loss: 0.5895 | Accuracy: 0.6925
# Epoch 302 | Loss: 0.5894 | Accuracy: 0.6925
# Epoch 303 | Loss: 0.5893 | Accuracy: 0.6926
# Epoch 304 | Loss: 0.5892 | Accuracy: 0.6924
# Epoch 305 | Loss: 0.5891 | Accuracy: 0.6918
# Epoch 306 | Loss: 0.5890 | Accuracy: 0.6914
# Epoch 307 | Loss: 0.5889 | Accuracy: 0.6913
# Epoch 308 | Loss: 0.5888 | Accuracy: 0.6912
# Epoch 309 | Loss: 0.5887 | Accuracy: 0.6910
# Epoch 310 | Loss: 0.5886 | Accuracy: 0.6912
# Epoch 311 | Loss: 0.5885 | Accuracy: 0.6908
# Epoch 312 | Loss: 0.5884 | Accuracy: 0.6914
# Epoch 313 | Loss: 0.5883 | Accuracy: 0.6913
# Epoch 314 | Loss: 0.5882 | Accuracy: 0.6908
# Epoch 315 | Loss: 0.5881 | Accuracy: 0.6906
# Epoch 316 | Loss: 0.5880 | Accuracy: 0.6904
# Epoch 317 | Loss: 0.5879 | Accuracy: 0.6905
# Epoch 318 | Loss: 0.5878 | Accuracy: 0.6901
# Epoch 319 | Loss: 0.5877 | Accuracy: 0.6900
# Epoch 320 | Loss: 0.5876 | Accuracy: 0.6904
# Epoch 321 | Loss: 0.5875 | Accuracy: 0.6906
# Epoch 322 | Loss: 0.5874 | Accuracy: 0.6901
# Epoch 323 | Loss: 0.5873 | Accuracy: 0.6902
# Epoch 324 | Loss: 0.5872 | Accuracy: 0.6905
# Epoch 325 | Loss: 0.5871 | Accuracy: 0.6907
# Epoch 326 | Loss: 0.5870 | Accuracy: 0.6907
# Epoch 327 | Loss: 0.5869 | Accuracy: 0.6908
# Epoch 328 | Loss: 0.5868 | Accuracy: 0.6908
# Epoch 329 | Loss: 0.5868 | Accuracy: 0.6908
# Epoch 330 | Loss: 0.5867 | Accuracy: 0.6910
# Epoch 331 | Loss: 0.5866 | Accuracy: 0.6921
# Epoch 332 | Loss: 0.5865 | Accuracy: 0.6921
# Epoch 333 | Loss: 0.5864 | Accuracy: 0.6926
# Epoch 334 | Loss: 0.5863 | Accuracy: 0.6926
# Epoch 335 | Loss: 0.5862 | Accuracy: 0.6930
# Epoch 336 | Loss: 0.5861 | Accuracy: 0.6932
# Epoch 337 | Loss: 0.5860 | Accuracy: 0.6930
# Epoch 338 | Loss: 0.5860 | Accuracy: 0.6929
# Epoch 339 | Loss: 0.5859 | Accuracy: 0.6934
# Epoch 340 | Loss: 0.5858 | Accuracy: 0.6937
# Epoch 341 | Loss: 0.5857 | Accuracy: 0.6938
# Epoch 342 | Loss: 0.5856 | Accuracy: 0.6940
# Epoch 343 | Loss: 0.5855 | Accuracy: 0.6943
# Epoch 344 | Loss: 0.5854 | Accuracy: 0.6945
# Epoch 345 | Loss: 0.5853 | Accuracy: 0.6945
# Epoch 346 | Loss: 0.5853 | Accuracy: 0.6945
# Epoch 347 | Loss: 0.5852 | Accuracy: 0.6944
# Epoch 348 | Loss: 0.5851 | Accuracy: 0.6944
# Epoch 349 | Loss: 0.5850 | Accuracy: 0.6947
# Epoch 350 | Loss: 0.5849 | Accuracy: 0.6945
# Epoch 351 | Loss: 0.5848 | Accuracy: 0.6943
# Epoch 352 | Loss: 0.5848 | Accuracy: 0.6947
# Epoch 353 | Loss: 0.5847 | Accuracy: 0.6947
# Epoch 354 | Loss: 0.5846 | Accuracy: 0.6951
# Epoch 355 | Loss: 0.5845 | Accuracy: 0.6949
# Epoch 356 | Loss: 0.5844 | Accuracy: 0.6946
# Epoch 357 | Loss: 0.5844 | Accuracy: 0.6947
# Epoch 358 | Loss: 0.5843 | Accuracy: 0.6949
# Epoch 359 | Loss: 0.5842 | Accuracy: 0.6946
# Epoch 360 | Loss: 0.5841 | Accuracy: 0.6948
# Epoch 361 | Loss: 0.5840 | Accuracy: 0.6948
# Epoch 362 | Loss: 0.5840 | Accuracy: 0.6944
# Epoch 363 | Loss: 0.5839 | Accuracy: 0.6948
# Epoch 364 | Loss: 0.5838 | Accuracy: 0.6944
# Epoch 365 | Loss: 0.5837 | Accuracy: 0.6944
# Epoch 366 | Loss: 0.5837 | Accuracy: 0.6946
# Epoch 367 | Loss: 0.5836 | Accuracy: 0.6948
# Epoch 368 | Loss: 0.5835 | Accuracy: 0.6947
# Epoch 369 | Loss: 0.5834 | Accuracy: 0.6948
# Epoch 370 | Loss: 0.5834 | Accuracy: 0.6947
# Epoch 371 | Loss: 0.5833 | Accuracy: 0.6948
# Epoch 372 | Loss: 0.5832 | Accuracy: 0.6948
# Epoch 373 | Loss: 0.5831 | Accuracy: 0.6951
# Epoch 374 | Loss: 0.5831 | Accuracy: 0.6952
# Epoch 375 | Loss: 0.5830 | Accuracy: 0.6952
# Epoch 376 | Loss: 0.5829 | Accuracy: 0.6954
# Epoch 377 | Loss: 0.5828 | Accuracy: 0.6951
# Epoch 378 | Loss: 0.5828 | Accuracy: 0.6953
# Epoch 379 | Loss: 0.5827 | Accuracy: 0.6953
# Epoch 380 | Loss: 0.5826 | Accuracy: 0.6954
# Epoch 381 | Loss: 0.5825 | Accuracy: 0.6958
# Epoch 382 | Loss: 0.5825 | Accuracy: 0.6957
# Epoch 383 | Loss: 0.5824 | Accuracy: 0.6961
# Epoch 384 | Loss: 0.5823 | Accuracy: 0.6962
# Epoch 385 | Loss: 0.5822 | Accuracy: 0.6958
# Epoch 386 | Loss: 0.5822 | Accuracy: 0.6963
# Epoch 387 | Loss: 0.5821 | Accuracy: 0.6966
# Epoch 388 | Loss: 0.5820 | Accuracy: 0.6970
# Epoch 389 | Loss: 0.5820 | Accuracy: 0.6971
# Epoch 390 | Loss: 0.5819 | Accuracy: 0.6970
# Epoch 391 | Loss: 0.5818 | Accuracy: 0.6970
# Epoch 392 | Loss: 0.5817 | Accuracy: 0.6968
# Epoch 393 | Loss: 0.5817 | Accuracy: 0.6970
# Epoch 394 | Loss: 0.5816 | Accuracy: 0.6967
# Epoch 395 | Loss: 0.5815 | Accuracy: 0.6966
# Epoch 396 | Loss: 0.5815 | Accuracy: 0.6964
# Epoch 397 | Loss: 0.5814 | Accuracy: 0.6966
# Epoch 398 | Loss: 0.5813 | Accuracy: 0.6963
# Epoch 399 | Loss: 0.5813 | Accuracy: 0.6965
# Epoch 400 | Loss: 0.5812 | Accuracy: 0.6963
# Epoch 401 | Loss: 0.5811 | Accuracy: 0.6958
# Epoch 402 | Loss: 0.5811 | Accuracy: 0.6955
# Epoch 403 | Loss: 0.5810 | Accuracy: 0.6957
# Epoch 404 | Loss: 0.5810 | Accuracy: 0.6958
# Epoch 405 | Loss: 0.5809 | Accuracy: 0.6958
# Epoch 406 | Loss: 0.5808 | Accuracy: 0.6956
# Epoch 407 | Loss: 0.5808 | Accuracy: 0.6960
# Epoch 408 | Loss: 0.5807 | Accuracy: 0.6962
# Epoch 409 | Loss: 0.5806 | Accuracy: 0.6964
# Epoch 410 | Loss: 0.5806 | Accuracy: 0.6965
# Epoch 411 | Loss: 0.5805 | Accuracy: 0.6971
# Epoch 412 | Loss: 0.5805 | Accuracy: 0.6973
# Epoch 413 | Loss: 0.5804 | Accuracy: 0.6972
# Epoch 414 | Loss: 0.5803 | Accuracy: 0.6971
# Epoch 415 | Loss: 0.5803 | Accuracy: 0.6969
# Epoch 416 | Loss: 0.5802 | Accuracy: 0.6967
# Epoch 417 | Loss: 0.5802 | Accuracy: 0.6969
# Epoch 418 | Loss: 0.5801 | Accuracy: 0.6968
# Epoch 419 | Loss: 0.5800 | Accuracy: 0.6968
# Epoch 420 | Loss: 0.5800 | Accuracy: 0.6970
# Epoch 421 | Loss: 0.5799 | Accuracy: 0.6970
# Epoch 422 | Loss: 0.5799 | Accuracy: 0.6969
# Epoch 423 | Loss: 0.5798 | Accuracy: 0.6970
# Epoch 424 | Loss: 0.5798 | Accuracy: 0.6968
# Epoch 425 | Loss: 0.5797 | Accuracy: 0.6969
# Epoch 426 | Loss: 0.5796 | Accuracy: 0.6971
# Epoch 427 | Loss: 0.5796 | Accuracy: 0.6971
# Epoch 428 | Loss: 0.5795 | Accuracy: 0.6971
# Epoch 429 | Loss: 0.5795 | Accuracy: 0.6972
# Epoch 430 | Loss: 0.5794 | Accuracy: 0.6971
# Epoch 431 | Loss: 0.5794 | Accuracy: 0.6969
# Epoch 432 | Loss: 0.5793 | Accuracy: 0.6971
# Epoch 433 | Loss: 0.5793 | Accuracy: 0.6972
# Epoch 434 | Loss: 0.5792 | Accuracy: 0.6972
# Epoch 435 | Loss: 0.5791 | Accuracy: 0.6978
# Epoch 436 | Loss: 0.5791 | Accuracy: 0.6978
# Epoch 437 | Loss: 0.5790 | Accuracy: 0.6979
# Epoch 438 | Loss: 0.5790 | Accuracy: 0.6979
# Epoch 439 | Loss: 0.5789 | Accuracy: 0.6979
# Epoch 440 | Loss: 0.5789 | Accuracy: 0.6979
# Epoch 441 | Loss: 0.5788 | Accuracy: 0.6979
# Epoch 442 | Loss: 0.5788 | Accuracy: 0.6976
# Epoch 443 | Loss: 0.5787 | Accuracy: 0.6986
# Epoch 444 | Loss: 0.5787 | Accuracy: 0.6986
# Epoch 445 | Loss: 0.5786 | Accuracy: 0.6987
# Epoch 446 | Loss: 0.5786 | Accuracy: 0.6985
# Epoch 447 | Loss: 0.5785 | Accuracy: 0.6983
# Epoch 448 | Loss: 0.5785 | Accuracy: 0.6983
# Epoch 449 | Loss: 0.5784 | Accuracy: 0.6985
# Epoch 450 | Loss: 0.5784 | Accuracy: 0.6992
# Epoch 451 | Loss: 0.5783 | Accuracy: 0.6992
# Epoch 452 | Loss: 0.5782 | Accuracy: 0.6991
# Epoch 453 | Loss: 0.5782 | Accuracy: 0.6992
# Epoch 454 | Loss: 0.5781 | Accuracy: 0.6992
# Epoch 455 | Loss: 0.5781 | Accuracy: 0.6992
# Epoch 456 | Loss: 0.5780 | Accuracy: 0.6991
# Epoch 457 | Loss: 0.5780 | Accuracy: 0.6991
# Epoch 458 | Loss: 0.5779 | Accuracy: 0.6992
# Epoch 459 | Loss: 0.5779 | Accuracy: 0.6991
# Epoch 460 | Loss: 0.5778 | Accuracy: 0.6992
# Epoch 461 | Loss: 0.5778 | Accuracy: 0.6992
# Epoch 462 | Loss: 0.5777 | Accuracy: 0.6993
# Epoch 463 | Loss: 0.5777 | Accuracy: 0.6995
# Epoch 464 | Loss: 0.5776 | Accuracy: 0.6996
# Epoch 465 | Loss: 0.5776 | Accuracy: 0.7003
# Epoch 466 | Loss: 0.5775 | Accuracy: 0.7001
# Epoch 467 | Loss: 0.5774 | Accuracy: 0.7005
# Epoch 468 | Loss: 0.5774 | Accuracy: 0.7009
# Epoch 469 | Loss: 0.5773 | Accuracy: 0.7009
# Epoch 470 | Loss: 0.5773 | Accuracy: 0.7009
# Epoch 471 | Loss: 0.5772 | Accuracy: 0.7011
# Epoch 472 | Loss: 0.5772 | Accuracy: 0.7013
# Epoch 473 | Loss: 0.5771 | Accuracy: 0.7014
# Epoch 474 | Loss: 0.5771 | Accuracy: 0.7014
# Epoch 475 | Loss: 0.5770 | Accuracy: 0.7009
# Epoch 476 | Loss: 0.5769 | Accuracy: 0.7007
# Epoch 477 | Loss: 0.5769 | Accuracy: 0.7007
# Epoch 478 | Loss: 0.5768 | Accuracy: 0.7005
# Epoch 479 | Loss: 0.5768 | Accuracy: 0.7005
# Epoch 480 | Loss: 0.5767 | Accuracy: 0.7008
# Epoch 481 | Loss: 0.5767 | Accuracy: 0.7009
# Epoch 482 | Loss: 0.5766 | Accuracy: 0.7008
# Epoch 483 | Loss: 0.5766 | Accuracy: 0.7011
# Epoch 484 | Loss: 0.5765 | Accuracy: 0.7012
# Epoch 485 | Loss: 0.5764 | Accuracy: 0.7009
# Epoch 486 | Loss: 0.5764 | Accuracy: 0.7011
# Epoch 487 | Loss: 0.5763 | Accuracy: 0.7009
# Epoch 488 | Loss: 0.5763 | Accuracy: 0.7007
# Epoch 489 | Loss: 0.5762 | Accuracy: 0.7007
# Epoch 490 | Loss: 0.5762 | Accuracy: 0.7008
# Epoch 491 | Loss: 0.5761 | Accuracy: 0.7008
# Epoch 492 | Loss: 0.5761 | Accuracy: 0.7003
# Epoch 493 | Loss: 0.5760 | Accuracy: 0.7002
# Epoch 494 | Loss: 0.5760 | Accuracy: 0.7000
# Epoch 495 | Loss: 0.5759 | Accuracy: 0.7005
# Epoch 496 | Loss: 0.5759 | Accuracy: 0.7003
# Epoch 497 | Loss: 0.5758 | Accuracy: 0.7004
# Epoch 498 | Loss: 0.5758 | Accuracy: 0.7002
# Epoch 499 | Loss: 0.5757 | Accuracy: 0.6999
# Epoch 500 | Loss: 0.5756 | Accuracy: 0.7003
# Epoch 501 | Loss: 0.5756 | Accuracy: 0.7002
# Epoch 502 | Loss: 0.5755 | Accuracy: 0.7006
# Epoch 503 | Loss: 0.5755 | Accuracy: 0.7011
# Epoch 504 | Loss: 0.5754 | Accuracy: 0.7011
# Epoch 505 | Loss: 0.5754 | Accuracy: 0.7012
# Epoch 506 | Loss: 0.5753 | Accuracy: 0.7016
# Epoch 507 | Loss: 0.5753 | Accuracy: 0.7017
# Epoch 508 | Loss: 0.5752 | Accuracy: 0.7018
# Epoch 509 | Loss: 0.5751 | Accuracy: 0.7015
# Epoch 510 | Loss: 0.5751 | Accuracy: 0.7019
# Epoch 511 | Loss: 0.5750 | Accuracy: 0.7023
# Epoch 512 | Loss: 0.5750 | Accuracy: 0.7027
# Epoch 513 | Loss: 0.5749 | Accuracy: 0.7028
# Epoch 514 | Loss: 0.5749 | Accuracy: 0.7023
# Epoch 515 | Loss: 0.5748 | Accuracy: 0.7017
# Epoch 516 | Loss: 0.5748 | Accuracy: 0.7018
# Epoch 517 | Loss: 0.5747 | Accuracy: 0.7021
# Epoch 518 | Loss: 0.5747 | Accuracy: 0.7021
# Epoch 519 | Loss: 0.5746 | Accuracy: 0.7024
# Epoch 520 | Loss: 0.5746 | Accuracy: 0.7025
# Epoch 521 | Loss: 0.5745 | Accuracy: 0.7026
# Epoch 522 | Loss: 0.5745 | Accuracy: 0.7026
# Epoch 523 | Loss: 0.5744 | Accuracy: 0.7022
# Epoch 524 | Loss: 0.5744 | Accuracy: 0.7019
# Epoch 525 | Loss: 0.5743 | Accuracy: 0.7022
# Epoch 526 | Loss: 0.5743 | Accuracy: 0.7021
# Epoch 527 | Loss: 0.5742 | Accuracy: 0.7025
# Epoch 528 | Loss: 0.5742 | Accuracy: 0.7027
# Epoch 529 | Loss: 0.5741 | Accuracy: 0.7026
# Epoch 530 | Loss: 0.5741 | Accuracy: 0.7027
# Epoch 531 | Loss: 0.5740 | Accuracy: 0.7028
# Epoch 532 | Loss: 0.5740 | Accuracy: 0.7034
# Epoch 533 | Loss: 0.5739 | Accuracy: 0.7036
# Epoch 534 | Loss: 0.5738 | Accuracy: 0.7035
# Epoch 535 | Loss: 0.5738 | Accuracy: 0.7035
# Epoch 536 | Loss: 0.5738 | Accuracy: 0.7038
# Epoch 537 | Loss: 0.5737 | Accuracy: 0.7040
# Epoch 538 | Loss: 0.5736 | Accuracy: 0.7044
# Epoch 539 | Loss: 0.5736 | Accuracy: 0.7046
# Epoch 540 | Loss: 0.5736 | Accuracy: 0.7045
# Epoch 541 | Loss: 0.5735 | Accuracy: 0.7048
# Epoch 542 | Loss: 0.5735 | Accuracy: 0.7048
# Epoch 543 | Loss: 0.5734 | Accuracy: 0.7055
# Epoch 544 | Loss: 0.5734 | Accuracy: 0.7052
# Epoch 545 | Loss: 0.5733 | Accuracy: 0.7052
# Epoch 546 | Loss: 0.5733 | Accuracy: 0.7052
# Epoch 547 | Loss: 0.5732 | Accuracy: 0.7053
# Epoch 548 | Loss: 0.5732 | Accuracy: 0.7057
# Epoch 549 | Loss: 0.5731 | Accuracy: 0.7057
# Epoch 550 | Loss: 0.5731 | Accuracy: 0.7057
# Epoch 551 | Loss: 0.5730 | Accuracy: 0.7059
# Epoch 552 | Loss: 0.5730 | Accuracy: 0.7057
# Epoch 553 | Loss: 0.5729 | Accuracy: 0.7058
# Epoch 554 | Loss: 0.5729 | Accuracy: 0.7061
# Epoch 555 | Loss: 0.5728 | Accuracy: 0.7061
# Epoch 556 | Loss: 0.5728 | Accuracy: 0.7060
# Epoch 557 | Loss: 0.5727 | Accuracy: 0.7058
# Epoch 558 | Loss: 0.5727 | Accuracy: 0.7058
# Epoch 559 | Loss: 0.5726 | Accuracy: 0.7057
# Epoch 560 | Loss: 0.5726 | Accuracy: 0.7055
# Epoch 561 | Loss: 0.5725 | Accuracy: 0.7058
# Epoch 562 | Loss: 0.5725 | Accuracy: 0.7059
# Epoch 563 | Loss: 0.5724 | Accuracy: 0.7060
# Epoch 564 | Loss: 0.5724 | Accuracy: 0.7061
# Epoch 565 | Loss: 0.5723 | Accuracy: 0.7058
# Epoch 566 | Loss: 0.5723 | Accuracy: 0.7061
# Epoch 567 | Loss: 0.5722 | Accuracy: 0.7062
# Epoch 568 | Loss: 0.5722 | Accuracy: 0.7060
# Epoch 569 | Loss: 0.5721 | Accuracy: 0.7060
# Epoch 570 | Loss: 0.5721 | Accuracy: 0.7060
# Epoch 571 | Loss: 0.5720 | Accuracy: 0.7059
# Epoch 572 | Loss: 0.5720 | Accuracy: 0.7063
# Epoch 573 | Loss: 0.5719 | Accuracy: 0.7062
# Epoch 574 | Loss: 0.5719 | Accuracy: 0.7061
# Epoch 575 | Loss: 0.5718 | Accuracy: 0.7064
# Epoch 576 | Loss: 0.5718 | Accuracy: 0.7061
# Epoch 577 | Loss: 0.5717 | Accuracy: 0.7061
# Epoch 578 | Loss: 0.5717 | Accuracy: 0.7057
# Epoch 579 | Loss: 0.5716 | Accuracy: 0.7055
# Epoch 580 | Loss: 0.5716 | Accuracy: 0.7055
# Epoch 581 | Loss: 0.5715 | Accuracy: 0.7058
# Epoch 582 | Loss: 0.5715 | Accuracy: 0.7056
# Epoch 583 | Loss: 0.5714 | Accuracy: 0.7059
# Epoch 584 | Loss: 0.5713 | Accuracy: 0.7061
# Epoch 585 | Loss: 0.5713 | Accuracy: 0.7059
# Epoch 586 | Loss: 0.5712 | Accuracy: 0.7056
# Epoch 587 | Loss: 0.5712 | Accuracy: 0.7054
# Epoch 588 | Loss: 0.5711 | Accuracy: 0.7054
# Epoch 589 | Loss: 0.5711 | Accuracy: 0.7054
# Epoch 590 | Loss: 0.5710 | Accuracy: 0.7056
# Epoch 591 | Loss: 0.5710 | Accuracy: 0.7056
# Epoch 592 | Loss: 0.5709 | Accuracy: 0.7056
# Epoch 593 | Loss: 0.5709 | Accuracy: 0.7056
# Epoch 594 | Loss: 0.5708 | Accuracy: 0.7059
# Epoch 595 | Loss: 0.5708 | Accuracy: 0.7061
# Epoch 596 | Loss: 0.5707 | Accuracy: 0.7060
# Epoch 597 | Loss: 0.5707 | Accuracy: 0.7061
# Epoch 598 | Loss: 0.5706 | Accuracy: 0.7062
# Epoch 599 | Loss: 0.5706 | Accuracy: 0.7061
# Epoch 600 | Loss: 0.5705 | Accuracy: 0.7061
# Epoch 601 | Loss: 0.5705 | Accuracy: 0.7066
# Epoch 602 | Loss: 0.5704 | Accuracy: 0.7072
# Epoch 603 | Loss: 0.5704 | Accuracy: 0.7071
# Epoch 604 | Loss: 0.5703 | Accuracy: 0.7066
# Epoch 605 | Loss: 0.5703 | Accuracy: 0.7065
# Epoch 606 | Loss: 0.5702 | Accuracy: 0.7071
# Epoch 607 | Loss: 0.5702 | Accuracy: 0.7071
# Epoch 608 | Loss: 0.5701 | Accuracy: 0.7071
# Epoch 609 | Loss: 0.5700 | Accuracy: 0.7069
# Epoch 610 | Loss: 0.5700 | Accuracy: 0.7076
# Epoch 611 | Loss: 0.5699 | Accuracy: 0.7076
# Epoch 612 | Loss: 0.5699 | Accuracy: 0.7073
# Epoch 613 | Loss: 0.5698 | Accuracy: 0.7074
# Epoch 614 | Loss: 0.5698 | Accuracy: 0.7074
# Epoch 615 | Loss: 0.5698 | Accuracy: 0.7068
# Epoch 616 | Loss: 0.5697 | Accuracy: 0.7073
# Epoch 617 | Loss: 0.5696 | Accuracy: 0.7074
# Epoch 618 | Loss: 0.5696 | Accuracy: 0.7078
# Epoch 619 | Loss: 0.5695 | Accuracy: 0.7073
# Epoch 620 | Loss: 0.5695 | Accuracy: 0.7072
# Epoch 621 | Loss: 0.5694 | Accuracy: 0.7069
# Epoch 622 | Loss: 0.5694 | Accuracy: 0.7066
# Epoch 623 | Loss: 0.5693 | Accuracy: 0.7072
# Epoch 624 | Loss: 0.5693 | Accuracy: 0.7079
# Epoch 625 | Loss: 0.5692 | Accuracy: 0.7078
# Epoch 626 | Loss: 0.5692 | Accuracy: 0.7084
# Epoch 627 | Loss: 0.5691 | Accuracy: 0.7086
# Epoch 628 | Loss: 0.5691 | Accuracy: 0.7085
# Epoch 629 | Loss: 0.5690 | Accuracy: 0.7086
# Epoch 630 | Loss: 0.5690 | Accuracy: 0.7085
# Epoch 631 | Loss: 0.5689 | Accuracy: 0.7084
# Epoch 632 | Loss: 0.5689 | Accuracy: 0.7084
# Epoch 633 | Loss: 0.5688 | Accuracy: 0.7081
# Epoch 634 | Loss: 0.5688 | Accuracy: 0.7079
# Epoch 635 | Loss: 0.5688 | Accuracy: 0.7083
# Epoch 636 | Loss: 0.5687 | Accuracy: 0.7090
# Epoch 637 | Loss: 0.5687 | Accuracy: 0.7090
# Epoch 638 | Loss: 0.5686 | Accuracy: 0.7092
# Epoch 639 | Loss: 0.5686 | Accuracy: 0.7088
# Epoch 640 | Loss: 0.5685 | Accuracy: 0.7089
# Epoch 641 | Loss: 0.5685 | Accuracy: 0.7089
# Epoch 642 | Loss: 0.5684 | Accuracy: 0.7091
# Epoch 643 | Loss: 0.5684 | Accuracy: 0.7093
# Epoch 644 | Loss: 0.5683 | Accuracy: 0.7087
# Epoch 645 | Loss: 0.5683 | Accuracy: 0.7087
# Epoch 646 | Loss: 0.5682 | Accuracy: 0.7087
# Epoch 647 | Loss: 0.5682 | Accuracy: 0.7090
# Epoch 648 | Loss: 0.5681 | Accuracy: 0.7098
# Epoch 649 | Loss: 0.5681 | Accuracy: 0.7097
# Epoch 650 | Loss: 0.5680 | Accuracy: 0.7096
# Epoch 651 | Loss: 0.5680 | Accuracy: 0.7100
# Epoch 652 | Loss: 0.5680 | Accuracy: 0.7098
# Epoch 653 | Loss: 0.5679 | Accuracy: 0.7097
# Epoch 654 | Loss: 0.5679 | Accuracy: 0.7098
# Epoch 655 | Loss: 0.5678 | Accuracy: 0.7095
# Epoch 656 | Loss: 0.5678 | Accuracy: 0.7095
# Epoch 657 | Loss: 0.5677 | Accuracy: 0.7093
# Epoch 658 | Loss: 0.5677 | Accuracy: 0.7095
# Epoch 659 | Loss: 0.5676 | Accuracy: 0.7096
# Epoch 660 | Loss: 0.5676 | Accuracy: 0.7100
# Epoch 661 | Loss: 0.5675 | Accuracy: 0.7102
# Epoch 662 | Loss: 0.5675 | Accuracy: 0.7099
# Epoch 663 | Loss: 0.5674 | Accuracy: 0.7100
# Epoch 664 | Loss: 0.5674 | Accuracy: 0.7109
# Epoch 665 | Loss: 0.5673 | Accuracy: 0.7099
# Epoch 666 | Loss: 0.5673 | Accuracy: 0.7100
# Epoch 667 | Loss: 0.5672 | Accuracy: 0.7097
# Epoch 668 | Loss: 0.5672 | Accuracy: 0.7098
# Epoch 669 | Loss: 0.5671 | Accuracy: 0.7099
# Epoch 670 | Loss: 0.5671 | Accuracy: 0.7098
# Epoch 671 | Loss: 0.5670 | Accuracy: 0.7100
# Epoch 672 | Loss: 0.5670 | Accuracy: 0.7102
# Epoch 673 | Loss: 0.5669 | Accuracy: 0.7102
# Epoch 674 | Loss: 0.5669 | Accuracy: 0.7101
# Epoch 675 | Loss: 0.5668 | Accuracy: 0.7101
# Epoch 676 | Loss: 0.5668 | Accuracy: 0.7102
# Epoch 677 | Loss: 0.5667 | Accuracy: 0.7105
# Epoch 678 | Loss: 0.5667 | Accuracy: 0.7106
# Epoch 679 | Loss: 0.5666 | Accuracy: 0.7109
# Epoch 680 | Loss: 0.5666 | Accuracy: 0.7112
# Epoch 681 | Loss: 0.5665 | Accuracy: 0.7114
# Epoch 682 | Loss: 0.5665 | Accuracy: 0.7113
# Epoch 683 | Loss: 0.5664 | Accuracy: 0.7118
# Epoch 684 | Loss: 0.5664 | Accuracy: 0.7117
# Epoch 685 | Loss: 0.5663 | Accuracy: 0.7113
# Epoch 686 | Loss: 0.5663 | Accuracy: 0.7113
# Epoch 687 | Loss: 0.5662 | Accuracy: 0.7113
# Epoch 688 | Loss: 0.5662 | Accuracy: 0.7114
# Epoch 689 | Loss: 0.5661 | Accuracy: 0.7117
# Epoch 690 | Loss: 0.5661 | Accuracy: 0.7118
# Epoch 691 | Loss: 0.5660 | Accuracy: 0.7118
# Epoch 692 | Loss: 0.5660 | Accuracy: 0.7119
# Epoch 693 | Loss: 0.5659 | Accuracy: 0.7117
# Epoch 694 | Loss: 0.5659 | Accuracy: 0.7115
# Epoch 695 | Loss: 0.5658 | Accuracy: 0.7115
# Epoch 696 | Loss: 0.5658 | Accuracy: 0.7112
# Epoch 697 | Loss: 0.5657 | Accuracy: 0.7117
# Epoch 698 | Loss: 0.5657 | Accuracy: 0.7117
# Epoch 699 | Loss: 0.5656 | Accuracy: 0.7116
# Epoch 700 | Loss: 0.5656 | Accuracy: 0.7113
# Epoch 701 | Loss: 0.5655 | Accuracy: 0.7111
# Epoch 702 | Loss: 0.5655 | Accuracy: 0.7118
# Epoch 703 | Loss: 0.5654 | Accuracy: 0.7116
# Epoch 704 | Loss: 0.5654 | Accuracy: 0.7119
# Epoch 705 | Loss: 0.5653 | Accuracy: 0.7119
# Epoch 706 | Loss: 0.5653 | Accuracy: 0.7119
# Epoch 707 | Loss: 0.5652 | Accuracy: 0.7125
# Epoch 708 | Loss: 0.5652 | Accuracy: 0.7125
# Epoch 709 | Loss: 0.5651 | Accuracy: 0.7123
# Epoch 710 | Loss: 0.5651 | Accuracy: 0.7122
# Epoch 711 | Loss: 0.5650 | Accuracy: 0.7121
# Epoch 712 | Loss: 0.5650 | Accuracy: 0.7120
# Epoch 713 | Loss: 0.5649 | Accuracy: 0.7125
# Epoch 714 | Loss: 0.5649 | Accuracy: 0.7128
# Epoch 715 | Loss: 0.5648 | Accuracy: 0.7126
# Epoch 716 | Loss: 0.5648 | Accuracy: 0.7124
# Epoch 717 | Loss: 0.5647 | Accuracy: 0.7125
# Epoch 718 | Loss: 0.5647 | Accuracy: 0.7126
# Epoch 719 | Loss: 0.5646 | Accuracy: 0.7128
# Epoch 720 | Loss: 0.5646 | Accuracy: 0.7126
# Epoch 721 | Loss: 0.5645 | Accuracy: 0.7127
# Epoch 722 | Loss: 0.5645 | Accuracy: 0.7126
# Epoch 723 | Loss: 0.5644 | Accuracy: 0.7128
# Epoch 724 | Loss: 0.5644 | Accuracy: 0.7128
# Epoch 725 | Loss: 0.5643 | Accuracy: 0.7124
# Epoch 726 | Loss: 0.5643 | Accuracy: 0.7125
# Epoch 727 | Loss: 0.5642 | Accuracy: 0.7127
# Epoch 728 | Loss: 0.5642 | Accuracy: 0.7125
# Epoch 729 | Loss: 0.5641 | Accuracy: 0.7128
# Epoch 730 | Loss: 0.5641 | Accuracy: 0.7130
# Epoch 731 | Loss: 0.5640 | Accuracy: 0.7130
# Epoch 732 | Loss: 0.5639 | Accuracy: 0.7133
# Epoch 733 | Loss: 0.5639 | Accuracy: 0.7131
# Epoch 734 | Loss: 0.5639 | Accuracy: 0.7129
# Epoch 735 | Loss: 0.5638 | Accuracy: 0.7132
# Epoch 736 | Loss: 0.5638 | Accuracy: 0.7132
# Epoch 737 | Loss: 0.5637 | Accuracy: 0.7130
# Epoch 738 | Loss: 0.5637 | Accuracy: 0.7129
# Epoch 739 | Loss: 0.5636 | Accuracy: 0.7129
# Epoch 740 | Loss: 0.5636 | Accuracy: 0.7127
# Epoch 741 | Loss: 0.5635 | Accuracy: 0.7130
# Epoch 742 | Loss: 0.5635 | Accuracy: 0.7132
# Epoch 743 | Loss: 0.5634 | Accuracy: 0.7136
# Epoch 744 | Loss: 0.5634 | Accuracy: 0.7137
# Epoch 745 | Loss: 0.5634 | Accuracy: 0.7138
# Epoch 746 | Loss: 0.5633 | Accuracy: 0.7137
# Epoch 747 | Loss: 0.5633 | Accuracy: 0.7136
# Epoch 748 | Loss: 0.5632 | Accuracy: 0.7136
# Epoch 749 | Loss: 0.5632 | Accuracy: 0.7136
# Epoch 750 | Loss: 0.5631 | Accuracy: 0.7138
# Epoch 751 | Loss: 0.5631 | Accuracy: 0.7138
# Epoch 752 | Loss: 0.5630 | Accuracy: 0.7137
# Epoch 753 | Loss: 0.5630 | Accuracy: 0.7137
# Epoch 754 | Loss: 0.5629 | Accuracy: 0.7136
# Epoch 755 | Loss: 0.5629 | Accuracy: 0.7143
# Epoch 756 | Loss: 0.5628 | Accuracy: 0.7150
# Epoch 757 | Loss: 0.5628 | Accuracy: 0.7152
# Epoch 758 | Loss: 0.5627 | Accuracy: 0.7153
# Epoch 759 | Loss: 0.5627 | Accuracy: 0.7154
# Epoch 760 | Loss: 0.5626 | Accuracy: 0.7151
# Epoch 761 | Loss: 0.5626 | Accuracy: 0.7158
# Epoch 762 | Loss: 0.5625 | Accuracy: 0.7157
# Epoch 763 | Loss: 0.5625 | Accuracy: 0.7154
# Epoch 764 | Loss: 0.5624 | Accuracy: 0.7160
# Epoch 765 | Loss: 0.5624 | Accuracy: 0.7156
# Epoch 766 | Loss: 0.5623 | Accuracy: 0.7157
# Epoch 767 | Loss: 0.5623 | Accuracy: 0.7159
# Epoch 768 | Loss: 0.5622 | Accuracy: 0.7156
# Epoch 769 | Loss: 0.5622 | Accuracy: 0.7159
# Epoch 770 | Loss: 0.5621 | Accuracy: 0.7158
# Epoch 771 | Loss: 0.5621 | Accuracy: 0.7160
# Epoch 772 | Loss: 0.5620 | Accuracy: 0.7161
# Epoch 773 | Loss: 0.5620 | Accuracy: 0.7165
# Epoch 774 | Loss: 0.5620 | Accuracy: 0.7166
# Epoch 775 | Loss: 0.5619 | Accuracy: 0.7170
# Epoch 776 | Loss: 0.5619 | Accuracy: 0.7169
# Epoch 777 | Loss: 0.5618 | Accuracy: 0.7164
# Epoch 778 | Loss: 0.5618 | Accuracy: 0.7163
# Epoch 779 | Loss: 0.5617 | Accuracy: 0.7163
# Epoch 780 | Loss: 0.5617 | Accuracy: 0.7164
# Epoch 781 | Loss: 0.5616 | Accuracy: 0.7164
# Epoch 782 | Loss: 0.5616 | Accuracy: 0.7163
# Epoch 783 | Loss: 0.5616 | Accuracy: 0.7162
# Epoch 784 | Loss: 0.5615 | Accuracy: 0.7159
# Epoch 785 | Loss: 0.5615 | Accuracy: 0.7160
# Epoch 786 | Loss: 0.5614 | Accuracy: 0.7157
# Epoch 787 | Loss: 0.5614 | Accuracy: 0.7158
# Epoch 788 | Loss: 0.5613 | Accuracy: 0.7156
# Epoch 789 | Loss: 0.5613 | Accuracy: 0.7158
# Epoch 790 | Loss: 0.5612 | Accuracy: 0.7158
# Epoch 791 | Loss: 0.5612 | Accuracy: 0.7157
# Epoch 792 | Loss: 0.5612 | Accuracy: 0.7155
# Epoch 793 | Loss: 0.5611 | Accuracy: 0.7155
# Epoch 794 | Loss: 0.5611 | Accuracy: 0.7159
# Epoch 795 | Loss: 0.5610 | Accuracy: 0.7160
# Epoch 796 | Loss: 0.5610 | Accuracy: 0.7162
# Epoch 797 | Loss: 0.5609 | Accuracy: 0.7163
# Epoch 798 | Loss: 0.5609 | Accuracy: 0.7168
# Epoch 799 | Loss: 0.5608 | Accuracy: 0.7169
# Epoch 800 | Loss: 0.5608 | Accuracy: 0.7170
# Epoch 801 | Loss: 0.5607 | Accuracy: 0.7170
# Epoch 802 | Loss: 0.5607 | Accuracy: 0.7162
# Epoch 803 | Loss: 0.5607 | Accuracy: 0.7166
# Epoch 804 | Loss: 0.5606 | Accuracy: 0.7168
# Epoch 805 | Loss: 0.5606 | Accuracy: 0.7161
# Epoch 806 | Loss: 0.5605 | Accuracy: 0.7163
# Epoch 807 | Loss: 0.5605 | Accuracy: 0.7164
# Epoch 808 | Loss: 0.5604 | Accuracy: 0.7165
# Epoch 809 | Loss: 0.5604 | Accuracy: 0.7163
# Epoch 810 | Loss: 0.5603 | Accuracy: 0.7161
# Epoch 811 | Loss: 0.5603 | Accuracy: 0.7160
# Epoch 812 | Loss: 0.5602 | Accuracy: 0.7160
# Epoch 813 | Loss: 0.5602 | Accuracy: 0.7161
# Epoch 814 | Loss: 0.5601 | Accuracy: 0.7158
# Epoch 815 | Loss: 0.5601 | Accuracy: 0.7160
# Epoch 816 | Loss: 0.5601 | Accuracy: 0.7161
# Epoch 817 | Loss: 0.5600 | Accuracy: 0.7159
# Epoch 818 | Loss: 0.5600 | Accuracy: 0.7158
# Epoch 819 | Loss: 0.5599 | Accuracy: 0.7155
# Epoch 820 | Loss: 0.5599 | Accuracy: 0.7161
# Epoch 821 | Loss: 0.5598 | Accuracy: 0.7162
# Epoch 822 | Loss: 0.5598 | Accuracy: 0.7161
# Epoch 823 | Loss: 0.5597 | Accuracy: 0.7162
# Epoch 824 | Loss: 0.5597 | Accuracy: 0.7161
# Epoch 825 | Loss: 0.5596 | Accuracy: 0.7157
# Epoch 826 | Loss: 0.5596 | Accuracy: 0.7160
# Epoch 827 | Loss: 0.5596 | Accuracy: 0.7169
# Epoch 828 | Loss: 0.5595 | Accuracy: 0.7169
# Epoch 829 | Loss: 0.5595 | Accuracy: 0.7169
# Epoch 830 | Loss: 0.5594 | Accuracy: 0.7171
# Epoch 831 | Loss: 0.5593 | Accuracy: 0.7174
# Epoch 832 | Loss: 0.5593 | Accuracy: 0.7172
# Epoch 833 | Loss: 0.5593 | Accuracy: 0.7172
# Epoch 834 | Loss: 0.5592 | Accuracy: 0.7172
# Epoch 835 | Loss: 0.5592 | Accuracy: 0.7173
# Epoch 836 | Loss: 0.5591 | Accuracy: 0.7172
# Epoch 837 | Loss: 0.5591 | Accuracy: 0.7171
# Epoch 838 | Loss: 0.5590 | Accuracy: 0.7171
# Epoch 839 | Loss: 0.5590 | Accuracy: 0.7180
# Epoch 840 | Loss: 0.5589 | Accuracy: 0.7178
# Epoch 841 | Loss: 0.5589 | Accuracy: 0.7174
# Epoch 842 | Loss: 0.5588 | Accuracy: 0.7176
# Epoch 843 | Loss: 0.5588 | Accuracy: 0.7175
# Epoch 844 | Loss: 0.5587 | Accuracy: 0.7174
# Epoch 845 | Loss: 0.5586 | Accuracy: 0.7179
# Epoch 846 | Loss: 0.5586 | Accuracy: 0.7179
# Epoch 847 | Loss: 0.5585 | Accuracy: 0.7183
# Epoch 848 | Loss: 0.5585 | Accuracy: 0.7186
# Epoch 849 | Loss: 0.5584 | Accuracy: 0.7188
# Epoch 850 | Loss: 0.5584 | Accuracy: 0.7191
# Epoch 851 | Loss: 0.5583 | Accuracy: 0.7188
# Epoch 852 | Loss: 0.5583 | Accuracy: 0.7191
# Epoch 853 | Loss: 0.5582 | Accuracy: 0.7194
# Epoch 854 | Loss: 0.5582 | Accuracy: 0.7187
# Epoch 855 | Loss: 0.5581 | Accuracy: 0.7187
# Epoch 856 | Loss: 0.5580 | Accuracy: 0.7187
# Epoch 857 | Loss: 0.5580 | Accuracy: 0.7189
# Epoch 858 | Loss: 0.5579 | Accuracy: 0.7192
# Epoch 859 | Loss: 0.5579 | Accuracy: 0.7193
# Epoch 860 | Loss: 0.5578 | Accuracy: 0.7188
# Epoch 861 | Loss: 0.5578 | Accuracy: 0.7183
# Epoch 862 | Loss: 0.5577 | Accuracy: 0.7181
# Epoch 863 | Loss: 0.5577 | Accuracy: 0.7181
# Epoch 864 | Loss: 0.5576 | Accuracy: 0.7184
# Epoch 865 | Loss: 0.5576 | Accuracy: 0.7183
# Epoch 866 | Loss: 0.5575 | Accuracy: 0.7185
# Epoch 867 | Loss: 0.5575 | Accuracy: 0.7186
# Epoch 868 | Loss: 0.5574 | Accuracy: 0.7186
# Epoch 869 | Loss: 0.5574 | Accuracy: 0.7187
# Epoch 870 | Loss: 0.5573 | Accuracy: 0.7188
# Epoch 871 | Loss: 0.5573 | Accuracy: 0.7189
# Epoch 872 | Loss: 0.5572 | Accuracy: 0.7194
# Epoch 873 | Loss: 0.5572 | Accuracy: 0.7197
# Epoch 874 | Loss: 0.5571 | Accuracy: 0.7196
# Epoch 875 | Loss: 0.5571 | Accuracy: 0.7197
# Epoch 876 | Loss: 0.5570 | Accuracy: 0.7198
# Epoch 877 | Loss: 0.5570 | Accuracy: 0.7202
# Epoch 878 | Loss: 0.5569 | Accuracy: 0.7206
# Epoch 879 | Loss: 0.5569 | Accuracy: 0.7206
# Epoch 880 | Loss: 0.5568 | Accuracy: 0.7206
# Epoch 881 | Loss: 0.5568 | Accuracy: 0.7209
# Epoch 882 | Loss: 0.5567 | Accuracy: 0.7207
# Epoch 883 | Loss: 0.5567 | Accuracy: 0.7208
# Epoch 884 | Loss: 0.5566 | Accuracy: 0.7207
# Epoch 885 | Loss: 0.5566 | Accuracy: 0.7208
# Epoch 886 | Loss: 0.5565 | Accuracy: 0.7211
# Epoch 887 | Loss: 0.5565 | Accuracy: 0.7204
# Epoch 888 | Loss: 0.5564 | Accuracy: 0.7205
# Epoch 889 | Loss: 0.5564 | Accuracy: 0.7204
# Epoch 890 | Loss: 0.5563 | Accuracy: 0.7208
# Epoch 891 | Loss: 0.5563 | Accuracy: 0.7208
# Epoch 892 | Loss: 0.5562 | Accuracy: 0.7208
# Epoch 893 | Loss: 0.5562 | Accuracy: 0.7206
# Epoch 894 | Loss: 0.5561 | Accuracy: 0.7201
# Epoch 895 | Loss: 0.5561 | Accuracy: 0.7199
# Epoch 896 | Loss: 0.5560 | Accuracy: 0.7200
# Epoch 897 | Loss: 0.5560 | Accuracy: 0.7201
# Epoch 898 | Loss: 0.5559 | Accuracy: 0.7206
# Epoch 899 | Loss: 0.5559 | Accuracy: 0.7203
# Epoch 900 | Loss: 0.5558 | Accuracy: 0.7206
# Epoch 901 | Loss: 0.5558 | Accuracy: 0.7201
# Epoch 902 | Loss: 0.5557 | Accuracy: 0.7204
# Epoch 903 | Loss: 0.5557 | Accuracy: 0.7204
# Epoch 904 | Loss: 0.5557 | Accuracy: 0.7202
# Epoch 905 | Loss: 0.5556 | Accuracy: 0.7205
# Epoch 906 | Loss: 0.5556 | Accuracy: 0.7199
# Epoch 907 | Loss: 0.5555 | Accuracy: 0.7200
# Epoch 908 | Loss: 0.5555 | Accuracy: 0.7201
# Epoch 909 | Loss: 0.5554 | Accuracy: 0.7204
# Epoch 910 | Loss: 0.5554 | Accuracy: 0.7205
# Epoch 911 | Loss: 0.5553 | Accuracy: 0.7204
# Epoch 912 | Loss: 0.5553 | Accuracy: 0.7206
# Epoch 913 | Loss: 0.5553 | Accuracy: 0.7208
# Epoch 914 | Loss: 0.5552 | Accuracy: 0.7209
# Epoch 915 | Loss: 0.5552 | Accuracy: 0.7214
# Epoch 916 | Loss: 0.5551 | Accuracy: 0.7213
# Epoch 917 | Loss: 0.5551 | Accuracy: 0.7215
# Epoch 918 | Loss: 0.5550 | Accuracy: 0.7217
# Epoch 919 | Loss: 0.5550 | Accuracy: 0.7215
# Epoch 920 | Loss: 0.5550 | Accuracy: 0.7215
# Epoch 921 | Loss: 0.5549 | Accuracy: 0.7214
# Epoch 922 | Loss: 0.5549 | Accuracy: 0.7214
# Epoch 923 | Loss: 0.5548 | Accuracy: 0.7217
# Epoch 924 | Loss: 0.5548 | Accuracy: 0.7217
# Epoch 925 | Loss: 0.5548 | Accuracy: 0.7219
# Epoch 926 | Loss: 0.5547 | Accuracy: 0.7217
# Epoch 927 | Loss: 0.5547 | Accuracy: 0.7223
# Epoch 928 | Loss: 0.5546 | Accuracy: 0.7218
# Epoch 929 | Loss: 0.5546 | Accuracy: 0.7217
# Epoch 930 | Loss: 0.5545 | Accuracy: 0.7220
# Epoch 931 | Loss: 0.5545 | Accuracy: 0.7219
# Epoch 932 | Loss: 0.5545 | Accuracy: 0.7218
# Epoch 933 | Loss: 0.5544 | Accuracy: 0.7227
# Epoch 934 | Loss: 0.5544 | Accuracy: 0.7223
# Epoch 935 | Loss: 0.5543 | Accuracy: 0.7219
# Epoch 936 | Loss: 0.5543 | Accuracy: 0.7220
# Epoch 937 | Loss: 0.5543 | Accuracy: 0.7220
# Epoch 938 | Loss: 0.5542 | Accuracy: 0.7224
# Epoch 939 | Loss: 0.5542 | Accuracy: 0.7226
# Epoch 940 | Loss: 0.5541 | Accuracy: 0.7221
# Epoch 941 | Loss: 0.5541 | Accuracy: 0.7225
# Epoch 942 | Loss: 0.5541 | Accuracy: 0.7225
# Epoch 943 | Loss: 0.5540 | Accuracy: 0.7223
# Epoch 944 | Loss: 0.5540 | Accuracy: 0.7224
# Epoch 945 | Loss: 0.5540 | Accuracy: 0.7227
# Epoch 946 | Loss: 0.5539 | Accuracy: 0.7223
# Epoch 947 | Loss: 0.5539 | Accuracy: 0.7226
# Epoch 948 | Loss: 0.5538 | Accuracy: 0.7229
# Epoch 949 | Loss: 0.5538 | Accuracy: 0.7233
# Epoch 950 | Loss: 0.5538 | Accuracy: 0.7232
# Epoch 951 | Loss: 0.5537 | Accuracy: 0.7233
# Epoch 952 | Loss: 0.5537 | Accuracy: 0.7231
# Epoch 953 | Loss: 0.5537 | Accuracy: 0.7231
# Epoch 954 | Loss: 0.5536 | Accuracy: 0.7232
# Epoch 955 | Loss: 0.5536 | Accuracy: 0.7231
# Epoch 956 | Loss: 0.5536 | Accuracy: 0.7225
# Epoch 957 | Loss: 0.5535 | Accuracy: 0.7228
# Epoch 958 | Loss: 0.5535 | Accuracy: 0.7231
# Epoch 959 | Loss: 0.5535 | Accuracy: 0.7231
# Epoch 960 | Loss: 0.5534 | Accuracy: 0.7234
# Epoch 961 | Loss: 0.5534 | Accuracy: 0.7234
# Epoch 962 | Loss: 0.5534 | Accuracy: 0.7232
# Epoch 963 | Loss: 0.5533 | Accuracy: 0.7228
# Epoch 964 | Loss: 0.5533 | Accuracy: 0.7231
# Epoch 965 | Loss: 0.5533 | Accuracy: 0.7233
# Epoch 966 | Loss: 0.5532 | Accuracy: 0.7234
# Epoch 967 | Loss: 0.5532 | Accuracy: 0.7232
# Epoch 968 | Loss: 0.5532 | Accuracy: 0.7231
# Epoch 969 | Loss: 0.5531 | Accuracy: 0.7235
# Epoch 970 | Loss: 0.5531 | Accuracy: 0.7232
# Epoch 971 | Loss: 0.5531 | Accuracy: 0.7230
# Epoch 972 | Loss: 0.5530 | Accuracy: 0.7240
# Epoch 973 | Loss: 0.5530 | Accuracy: 0.7232
# Epoch 974 | Loss: 0.5530 | Accuracy: 0.7237
# Epoch 975 | Loss: 0.5529 | Accuracy: 0.7237
# Epoch 976 | Loss: 0.5529 | Accuracy: 0.7239
# Epoch 977 | Loss: 0.5529 | Accuracy: 0.7239
# Epoch 978 | Loss: 0.5528 | Accuracy: 0.7237
# Epoch 979 | Loss: 0.5528 | Accuracy: 0.7235
# Epoch 980 | Loss: 0.5528 | Accuracy: 0.7232
# Epoch 981 | Loss: 0.5527 | Accuracy: 0.7235
# Epoch 982 | Loss: 0.5527 | Accuracy: 0.7232
# Epoch 983 | Loss: 0.5527 | Accuracy: 0.7232
# Epoch 984 | Loss: 0.5526 | Accuracy: 0.7232
# Epoch 985 | Loss: 0.5526 | Accuracy: 0.7232
# Epoch 986 | Loss: 0.5526 | Accuracy: 0.7230
# Epoch 987 | Loss: 0.5526 | Accuracy: 0.7232
# Epoch 988 | Loss: 0.5525 | Accuracy: 0.7235
# Epoch 989 | Loss: 0.5525 | Accuracy: 0.7237
# Epoch 990 | Loss: 0.5525 | Accuracy: 0.7234
# Epoch 991 | Loss: 0.5524 | Accuracy: 0.7234
# Epoch 992 | Loss: 0.5524 | Accuracy: 0.7235
# Epoch 993 | Loss: 0.5524 | Accuracy: 0.7234
# Epoch 994 | Loss: 0.5523 | Accuracy: 0.7234
# Epoch 995 | Loss: 0.5523 | Accuracy: 0.7233
# Epoch 996 | Loss: 0.5523 | Accuracy: 0.7233
# Epoch 997 | Loss: 0.5522 | Accuracy: 0.7235
# Epoch 998 | Loss: 0.5522 | Accuracy: 0.7234
# Epoch 999 | Loss: 0.5522 | Accuracy: 0.7228
# Epoch 1000 | Loss: 0.5522 | Accuracy: 0.7232
# Training complete!

# %% [markdown]
# #### Lets plot the loss curve and training accuracy to observe how well our model learns over iterations

# %%
fig, axes = plt.subplots(1, 2, figsize=(8, 4))

# -------------------------
# Loss plot
# -------------------------
axes[0].plot(train_losses)
axes[0].set_xlabel("Epoch")
axes[0].set_ylabel("Loss")
axes[0].set_title("Training Loss")

# -------------------------
# Accuracy plot
# -------------------------
axes[1].plot(train_accuracies)
axes[1].set_ylim(0, 1)
axes[1].set_xlabel("Epoch")
axes[1].set_ylabel("Accuracy")
axes[1].set_title("Training Accuracy")

plt.tight_layout()
plt.show()

# %% [markdown]
# # Running the  Trained TCR CNN on Test Data
#
# Now that we are done with training, lets evaluate our CNN by testing it on unseen TCR repertoire data.
# Instead of using individual sequence predictions, we aggregate results to obtain **sample-level scores**.
#
# ---
#
# ## Inference Workflow
#
# ### Step 1 — Load Trained Model (if the model is saved to a path)
#
# A pretrained CNN is used to generate predictions without further training.
#
# ---
#
# ### Step 2 — Prepare Test Data
#
# Each file contains multiple TCR sequences.
#
# Each sequence is:
#
# * Encoded using AAindex features
# * Converted into a fixed-shape tensor for the model
#
# ---
#
# ### Step 3 — Run Predictions
#
# The model outputs a cancer probability for each sequence.
#
# ---
#
# ### Step 4 — Aggregate Results
#
# For each sample, we compute:
#
# > Mean cancer probability across all sequences
#
# This gives one score per repertoire.
#
# ---
#
# ## Evaluation
#
# We assess performance using:
#
# ### ROC-AUC
#
# Measures how well the model separates cancer and control samples.
#
# ### F1 Score
#
# Computed using a fixed threshold on sample-level scores.
#
# ### Boxplot
#
# Visualises distribution differences between cancer and control samples.
#
# ---
#
# ## Key Idea
#
# The model predicts at the **sequence level**, but evaluation is performed at the **sample level** by aggregating predictions.
#
# ---

# %%
def load_sequences(file_path):
    """
    Load amino acid sequences from a text file.

    Each line in the file is assumed to contain one sequence.
    Empty lines are ignored.

    Parameters
    ----------
    file_path : Path or str
        Path to the sequence file.

    Returns
    -------
    list of str
        List of cleaned sequences.
    """
    with open(file_path) as f:
        return [line.strip() for line in f if line.strip()]


def encode_sequences(seqs):
    """
    Convert a list of amino acid sequences into AAindex feature tensors.

    Each sequence is transformed using `aaindex_encoding`, producing a
    fixed-length numeric representation suitable for CNN input.

    Parameters
    ----------
    seqs : list of str
        Amino acid sequences.

    Returns
    -------
    np.ndarray
        Array of shape:
        (num_sequences, sequence_length, num_features)
    """
    return np.array(
        [
            aaindex_encoding(seq, num_features, aaidx_dict)
            for seq in seqs
        ],
        dtype=np.float32
    )


def get_mean_cancer_prob(file_path, model):
    """
    Compute the mean cancer probability for all sequences in a single sample.

    This function treats each file as one biological sample (e.g., one patient
    or repertoire). It:
    1. loads all sequences in the file
    2. encodes them into feature tensors
    3. runs the trained model on each sequence
    4. converts logits to probabilities
    5. returns the mean probability across all sequences

    This produces a *sample-level cancer score*.

    Parameters
    ----------
    file_path : Path or str
        Path to a file containing sequences for one sample.

    model : torch.nn.Module
        Trained PyTorch model.

    Returns
    -------
    float or None
        Mean cancer probability for the sample.
        Returns None if file is empty.
    """
    # Load raw amino acid sequences for this sample
    seqs = load_sequences(file_path)

    # Skip empty samples
    if len(seqs) == 0:
        return None

    # Convert sequences → numerical feature representation
    X = encode_sequences(seqs)

    # Convert to PyTorch tensor and reshape for CNN:
    # (samples, features, sequence_length) → (batch, channels, features, sequence_length)
    X = torch.tensor(X).permute(0, 2, 1).unsqueeze(1)

    model.eval()

    with torch.no_grad():
        # Forward pass through model (logits for cancer vs control)
        logits = model(X)

        # Convert logits → probabilities
        probs = torch.softmax(logits, dim=1)[:, 1]  # cancer class probability

    # Aggregate sequence-level predictions into one sample-level score
    return probs.mean().item()

# %% [markdown]
# #### lets read in, preprocess, and run our trained deep learning model on the test datasets

# %%
# LOAD DIRECTORIES (each folder = biological group)
cancer_dir = Path("/content/FIMSA-training-workshop-1/data/tutorial_4/cancer_testing_data_dir")
control_dir = Path("/content/FIMSA-training-workshop-1/data/tutorial_4/control_testing_data_dir")

cancer_scores = []
control_scores = []
y_true = []
y_score = []

# cancer samples (label = 1)
for file in cancer_dir.glob("*"):
    score = get_mean_cancer_prob(file, model)
    if score is not None:
        cancer_scores.append(score)
        y_true.append(1)
        y_score.append(score)

# control samples (label = 0)
for file in control_dir.glob("*"):
    score = get_mean_cancer_prob(file, model)
    if score is not None:
        control_scores.append(score)
        y_true.append(0)
        y_score.append(score)


cancer_scores = np.array(cancer_scores)
control_scores = np.array(control_scores)

y_true = np.array(y_true)
y_score = np.array(y_score)

print(f"cancer samples: {len(cancer_scores)}")
print(f"control samples: {len(control_scores)}")
# Out:
# cancer samples: 20
# control samples: 71

# %%
from sklearn.metrics import roc_auc_score, roc_curve, f1_score

# AUC + ROC CURVE
auc = roc_auc_score(y_true, y_score)
print(f"Sample-level ROC-AUC: {auc:.4f}")

# -------------------------
# F1 SCORE (threshold = 0.5)
# -------------------------
y_pred = (np.array(y_score) >= 0.5).astype(int)
f1 = f1_score(y_true, y_pred)

print(f"Sample-level F1 score: {f1:.4f}")

fpr, tpr, _ = roc_curve(y_true, y_score)

# PLOTTING
plt.figure(figsize=(8, 4))

# --- boxplot ---
plt.subplot(1, 2, 1)
plt.boxplot(
    [cancer_scores, control_scores],
    labels=[f"Cancer ({len(cancer_scores)})", f"Control ({len(control_scores)})"]
)
plt.ylabel("Mean Cancer Probability per Sample")
plt.title("Sample-level Score Distribution")

# --- ROC curve ---
plt.subplot(1, 2, 2)
plt.plot(fpr, tpr)
plt.plot([0, 1], [0, 1], linestyle="--")
plt.xlabel("False Positive Rate")
plt.ylabel("True Positive Rate")
plt.title(f"ROC Curve (AUC = {auc:.3f})")

plt.tight_layout()
plt.show()
# Out:
# Sample-level ROC-AUC: 1.0000
# Sample-level F1 score: 1.0000
# /scratch/temp/24977282/ipykernel_604471/3110402149.py:24: MatplotlibDeprecationWarning: The 'labels' parameter of boxplot() has been renamed 'tick_labels' since Matplotlib 3.9; support for the old name will be dropped in 3.11.
#   plt.boxplot(

# %% [markdown]
# # Summary
#
# In this notebook, we explored:
#
# * The structure of TCR sequencing datasets
# * Common machine learning and deep learning libraries
# * Training a small deep learning model
# * Running inference with trained models
# * Biological interpretation and evaluation concepts
#
# Deep learning is becoming an increasingly important tool in computational immunology and bioinformatics, enabling researchers to uncover complex patterns in immune receptor data.
